# %%
import sys
sys.path.append("..")
import numpy as np
import matplotlib.pyplot as plt
from datasets.polynomials import Polynomial

# %%
quadratic = Polynomial()
x, y = quadratic.generate(100)
plt.scatter(x, y, label="train")
test_x, test_y = quadratic.generate(100, y_dev=0.2)
plt.scatter(test_x, test_y, c='r', label="test")
plt.legend()

print(quadratic)
# Out:
# -6.0291 + 0.6311x - 0.7301x^2

# %%
quadratic = Polynomial(order=6)
x, y = quadratic.generate(100)
plt.scatter(x, y)

print(quadratic)
# Out:
# 1.9157 - 3.0811x + 1.5862x^2 - 0.1853x^3 + 0.0345x^4 - 0.019x^5 - 0.0014x^6

# %%
multidimensional = Polynomial(order=1, dim=4)
x, y = multidimensional.generate(10)
print(f"x: {x}")
print(f"y: {y}")
# Out:
# x: [[ 2.68004966  1.76267028 -3.74506373 -5.81292141]
#  [-6.84432987  3.0183924   3.5674958  -3.3625004 ]
#  [-0.58952575  1.12022332 -2.42515876  3.74531733]
#  [-0.70302711 -3.97325551  4.52891674 -1.99110224]
#  [-1.26615821 -1.87554038 -6.25945998  1.88087986]
#  [-0.94662749 -2.27832497 -0.27131183 -4.533424  ]
#  [ 1.95004174 -6.02282998  5.73005572  1.98494318]
#  [ 2.50543498  0.31273798  2.14921187 -0.96966075]
#  [ 0.69360303 -0.3429968  -5.2283278  -0.88413349]
#  [ 1.59167265  1.74242161  1.93145949 -0.58842019]]
# y: [ 48.04107129 -56.98103841  22.86764308 -21.04314615  51.01714466
#    8.11493026 -12.46398119   6.82083286  51.52419152   2.60087823]

# %%
multidimensional_2 = Polynomial(order=2, dim=6)
x, y = multidimensional_2.generate(10)
print(f"x: {x}")
print(f"y: {y}")
# Out:
# x: [[-4.12003852  1.90932885 -2.91438388  0.94172426 -0.56152949 -3.72011721]
#  [-1.11390774  4.10407504  5.12374759  1.93874324 -2.93101957  0.8117966 ]
#  [ 2.78304848 -2.14499004  7.20915044  1.3244208   3.37435084  3.91902549]
#  [ 2.55226241  1.5931534  -3.19127848 -1.63095676  2.19834283  0.03794946]
#  [ 6.81103243 -1.61489617  1.61789136  0.93927363 -7.27242691  1.66789863]
#  [ 3.05194456 -1.67187149  1.58058858  3.23718087 -2.45301855 -3.67455024]
#  [-1.66873161 -1.82691584 -1.28002321  2.3276762   4.40547915  0.57444172]
#  [ 1.7633764   2.75107128  2.1691981   0.06739864  3.15433883  1.5022313 ]
#  [-2.46481742 -0.94483732 -3.66877572 -1.07169428  2.14685482 -0.13304241]
#  [-2.44160088 -4.13422733  1.9768554   1.15051161 -2.1324496   2.35666317]]
# y: [-47.07915803  10.86074222  15.63004027 -31.26900465  67.7398415
#   29.02766493 -34.31095024 -14.74606983 -53.7558871   -2.45442679]
