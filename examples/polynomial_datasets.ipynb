# %%
import sys
sys.path.append("..")
import numpy as np
import matplotlib.pyplot as plt
from datasets.polynomials import Polynomial

# %%
quadratic = Polynomial()
x, y = quadratic.generate(100)
plt.scatter(x, y, label="train")
test_x, test_y = quadratic.generate(100, y_dev=0.2)
plt.scatter(test_x, test_y, c='r', label="test")
plt.legend()

print(quadratic)
# Out:
# -6.7423 + 0.4294x - 0.0861x^2

# %%
quadratic = Polynomial(order=6)
x, y = quadratic.generate(100)
plt.scatter(x, y)

print(quadratic)
# Out:
# -0.2058 + 0.4376x + 0.1731x^2 - 0.0819x^3 - 0.0085x^4 - 0.0007x^5 + 0.0001x^6

# %%
multidimensional = Polynomial(order=1, dim=4)
x, y = multidimensional.generate(10)
print(x)
print(multidimensional.coefficients)
print(y)
# Out:
# [[ 3.98781190e+00  3.95659487e-01  3.68645170e+00 -6.75305187e+00]
#  [-6.20188700e-01 -1.35784313e+00 -4.71983405e+00 -3.01429415e+00]
#  [ 3.69821764e+00 -7.65043847e-01 -3.76338562e-01  9.00493497e-03]
#  [-9.04812763e+00 -3.20676404e+00  2.47521239e+00  2.27639936e+00]
#  [-2.94519618e+00  4.65234658e+00  2.41594032e+00  1.33021643e+00]
#  [ 2.98530134e+00 -2.03636393e-01  1.22427994e+00  2.58418058e+00]
#  [-4.83227579e+00  4.88962003e+00  6.48128128e-01 -7.32748425e+00]
#  [-1.51371667e+00  1.34571643e+00 -3.71203096e+00 -1.82887994e+00]
#  [-4.02247377e+00  4.05520303e+00 -1.70668728e+00 -1.64770447e+00]
#  [-5.32661199e+00  2.11913311e+00 -1.61198629e-01 -5.82166048e-01]]
# [-0.27643049 -0.13643933  0.02942461 -1.33683826  0.19741242]
# [-6.87451563  5.26435524  0.29429001 -1.91365506 -2.35139325 -3.16678473
#  -3.08195953  3.79411965  1.68821549  0.32231389]
