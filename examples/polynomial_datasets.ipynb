# %%
import sys
sys.path.append("..")
import numpy as np
import matplotlib.pyplot as plt
from datasets.polynomials import Polynomial

# %%
quadratic = Polynomial()

# %%
x, y = quadratic.generate(100)
plt.scatter(x, y)

print(quadratic)

x, y = quadratic.generate(100, noise=False)
# Out:
# 2.137412509823971 + 1.8164423869366517 + x - -0.9580310212680252 + x^2
